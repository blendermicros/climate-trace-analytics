# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT * FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv') 
    LIMIT 5
""").fetchdf()
print(result)b
# Out:
#   iso3_country sector               subsector start_time   end_time  gas  \
# 0          DNK  power  electricity-generation 2015-01-01 2015-12-31  co2
# 1          DNK  power  electricity-generation 2016-01-01 2016-12-31  co2
# 2          DNK  power  electricity-generation 2017-01-01 2017-12-31  co2
# 3          DNK  power  electricity-generation 2018-01-01 2018-12-31  co2
# 4          DNK  power  electricity-generation 2019-01-01 2019-12-31  co2
#
#    emissions_quantity emissions_quantity_units temporal_granularity  \
# 0            10367775                   tonnes               annual
# 1            12571690                   tonnes               annual
# 2             9329051                   tonnes               annual
# 3             9638555                   tonnes               annual
# 4             6349738                   tonnes               annual
#
#                 created_date              modified_date
# 0 2024-04-18 19:20:34.053284 2026-03-14 20:46:08.333882
# ...

# %%
result = conn.execute("""
    SELECT 
        COUNT(*) AS total_rows,
        COUNT(DISTINCT iso3_country) AS countries,
        COUNT(DISTINCT gas) AS gas_types,
        COUNT(DISTINCT subsector) AS subsectors,
        MIN(start_time) AS earliest_date,
        MAX(end_time) AS latest_date
    FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2.csv')
""").fetchdf()
print(result)
# Out:
#    total_rows  countries  gas_types  subsectors earliest_date latest_date
# 0          12          1          1           1    2015-01-01  2026-12-31

# %%
result = conn.execute("""
    Select
        Count(*) AS total_rows,
        Count(emissions_quantity) as emissions_quantity,
        count(emissions_quantity = null) as null
    FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2.csv')
""").fetchdf()
print(result)
# Out:
#    total_rows  emissions_quantity  null
# 0          12                  12     0

# %%
result = conn.execute("""
    SELECT 
        COUNT(*) AS total_rows,
        COUNT(emissions_quantity) AS rows_with_data,
        COUNT(*) - COUNT(emissions_quantity) AS null_rows
    FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv')
""").fetchdf()
print(result)
# Out:
#    total_rows  rows_with_data  null_rows
# 0          12              12          0

# %%
esult = conn.execute("""
    SELECT * FROM read_csv_auto('dataM<>??":KJ}{O|_)(*&^%$#@%^&*()_+}|{P"electricity-generation_country_emissions_v5_5_0 dk co2') 
    """).fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 esult = conn.execute("""
#       2     SELECT * FROM read_csv_auto('dataM<>??":KJ}{O|_)(*&^%$#@%^&*()_+}|{P"electricity-generation_country_emissions_v5_5_0 dk co2')
#       3     """).fetchdf()
#       4 print(result)
#
# IOException: IO Error: No files found that match the pattern "dataM<>??":KJ}{O|_)(*&^%$#@%^&*()_+}|{P"electricity-generation_country_emissions_v5_5_0 dk co2"
#
# LINE 2:     SELECT * FROM read_csv_auto('dataM<>??":KJ}{O|_)(*&^%$#@%^&*()_+}|{P"elec...
#                           ^

# %%
result = conn.execute("""
    SELECT * FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2') 
    """).fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = conn.execute("""
#       2     SELECT * FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2')
#       3     """).fetchdf()
#       4 print(result)
#
# IOException: IO Error: No files found that match the pattern "data/electricity-generation_country_emissions_v5_5_0 dk co2"
#
# LINE 2:     SELECT * FROM read_csv_auto('data/electricity-generation_country_emission...
#                           ^

# %%
result = conn.execute("""
    SELECT * FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv') 
    """).fetchdf()
print(result)
# Out:
#    iso3_country sector               subsector start_time   end_time  gas  \
# 0           DNK  power  electricity-generation 2015-01-01 2015-12-31  co2
# 1           DNK  power  electricity-generation 2016-01-01 2016-12-31  co2
# 2           DNK  power  electricity-generation 2017-01-01 2017-12-31  co2
# 3           DNK  power  electricity-generation 2018-01-01 2018-12-31  co2
# 4           DNK  power  electricity-generation 2019-01-01 2019-12-31  co2
# 5           DNK  power  electricity-generation 2020-01-01 2020-12-31  co2
# 6           DNK  power  electricity-generation 2021-01-01 2021-12-31  co2
# 7           DNK  power  electricity-generation 2022-01-01 2022-12-31  co2
# 8           DNK  power  electricity-generation 2023-01-01 2023-12-31  co2
# 9           DNK  power  electricity-generation 2024-01-01 2024-12-31  co2
# 10          DNK  power  electricity-generation 2025-01-01 2025-12-31  co2
# 11          DNK  power  electricity-generation 2026-01-01 2026-12-31  co2
#
# ...

# %%
result = conn.execute("""
    SELECT iso3_country FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv') 
    """).fetchdf()
print(result)
# Out:
#    iso3_country
# 0           DNK
# 1           DNK
# 2           DNK
# 3           DNK
# 4           DNK
# 5           DNK
# 6           DNK
# 7           DNK
# 8           DNK
# 9           DNK
# 10          DNK
# 11          DNK

# %%
result = conn.execute("""
    SELECT emissions_quantity,  FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv') 
    """).fetchdf()
print(result)
# Out:
#     emissions_quantity
# 0             10367775
# 1             12571690
# 2              9329051
# 3              9638555
# 4              6349738
# 5              5643056
# 6              7627075
# 7              7816318
# 8              5615619
# 9              5605587
# 10             4687723
# 11              437613

# %%
result = conn.execute("""
    SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv') 
    """).fetchdf()
    ORDER BY start_time ASC
print(result)
# Out:
#   Cell In[16], line 4
#     ORDER BY start_time ASC
#     ^
# IndentationError: unexpected indent

# %%
result = conn.execute("""
    SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv') 
    """).fetchdf()
ORDER BY start_time ASC
print(result)
# Out:
#   Cell In[17], line 4
#     ORDER BY start_time ASC
#           ^
# SyntaxError: invalid syntax

# %%
result = conn.execute("""
    SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv')
    ORDER BY start_time ASC
    """).fetchdf()
print(result)
# Out:
#     emissions_quantity start_time
# 0             10367775 2015-01-01
# 1             12571690 2016-01-01
# 2              9329051 2017-01-01
# 3              9638555 2018-01-01
# 4              6349738 2019-01-01
# 5              5643056 2020-01-01
# 6              7627075 2021-01-01
# 7              7816318 2022-01-01
# 8              5615619 2023-01-01
# 9              5605587 2024-01-01
# 10             4687723 2025-01-01
# 11              437613 2026-01-01

# %%
SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv')
    ORDER BY start_time ASC
# Out:
#   Cell In[19], line 1
#     SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv')
#            ^
# SyntaxError: invalid syntax

# %%
SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv')
    ORDER BY start_time ASC;
# Out:
#   Cell In[20], line 1
#     SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv')
#            ^
# SyntaxError: invalid syntax

# %%
result = conn.execute("""
    SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2.csv')
    WHERE emissions_quantity >10000000
    ORDER BY start_time ASC
    """).fetchdf()
print(result)
# Out:
#    emissions_quantity start_time
# 0            10367775 2015-01-01
# 1            12571690 2016-01-01

# %%
result = conn.execute("""
    SELECT emissions_quantity, start_time FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2e.csv')
    ORDER BY start_time ASC
    """).fetchdf()
print(result)
# Out:
#     emissions_quantity start_time
# 0             10367775 2015-01-01
# 1             12571690 2016-01-01
# 2              9329051 2017-01-01
# 3              9638555 2018-01-01
# 4              6349738 2019-01-01
# 5              5643056 2020-01-01
# 6              7627075 2021-01-01
# 7              7816318 2022-01-01
# 8              5615619 2023-01-01
# 9              5605587 2024-01-01
# 10             4687723 2025-01-01
# 11              437613 2026-01-01

# %%
result = conn.execute("""
    SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
    WHERE iso3_country = "DNK" OR "SWE" OR "NOR"
    GROUP BY iso3_country
    ORDER BY emissions_quantity ASC
    """).fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 result = conn.execute("""
#       2     SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
#       3     WHERE iso3_country = "DNK" OR "SWE" OR "NOR"
#       4     GROUP BY iso3_country
#
# BinderException: Binder Error: Referenced column "DNK" not found in FROM clause!
# Candidate bindings: "created_date"
#
# LINE 3:     WHERE iso3_country = "DNK" OR "SWE" OR "NOR"
#                                  ^

# %%
result = conn.execute("""
    SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
    WHERE iso3_country LIKE "DNK" OR "SWE" OR "NOR"
    GROUP BY iso3_country
    ORDER BY emissions_quantity ASC
    """).fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 result = conn.execute("""
#       2     SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
#       3     WHERE iso3_country LIKE "DNK" OR "SWE" OR "NOR"
#       4     GROUP BY iso3_country
#
# BinderException: Binder Error: Referenced column "DNK" not found in FROM clause!
# Candidate bindings: "created_date"
#
# LINE 3:     WHERE iso3_country LIKE "DNK" OR "SWE" OR "NOR"
#                                     ^

# %%
result = conn.execute("""
    SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
    WHERE iso3_country LIKE "DNK"
    GROUP BY iso3_country
    ORDER BY emissions_quantity ASC
    """).fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 result = conn.execute("""
#       2     SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
#       3     WHERE iso3_country LIKE "DNK"
#       4     GROUP BY iso3_country
#
# BinderException: Binder Error: Referenced column "DNK" not found in FROM clause!
# Candidate bindings: "created_date"
#
# LINE 3:     WHERE iso3_country LIKE "DNK"
#                                     ^

# %%
result = conn.execute("""
    SELECT iso3_country, sum(emissions_quantity) FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
    WHERE iso3_country IN ('DNK','SWE', 'NOR', 'FIN')
    GROUP BY iso3_country
    ORDER BY emissions_quantity ASC
    """).fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 result = conn.execute("""
#       2     SELECT iso3_country, sum(emissions_quantity) FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
#       3     WHERE iso3_country IN ('DNK','SWE', 'NOR', 'FIN')
#       4     GROUP BY iso3_country
#
# BinderException: Binder Error: column "emissions_quantity" must appear in the GROUP BY clause or must be part of an aggregate function.
# Either add it to the GROUP BY list, or use "ANY_VALUE(emissions_quantity)" if the exact value of "emissions_quantity" is not important.
#
# LINE 5:     ORDER BY emissions_quantity ASC
#                      ^

# %%
result = conn.execute("""
    SELECT iso3_country, SUM(emissions_quantity) AS total_emissions FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
    WHERE iso3_country IN ('DNK','SWE', 'NOR', 'FIN')
    AND start_time >= '2024-01-01'
    AND start_time < '2025-01-01'
    GROUP BY iso3_country
    ORDER BY total_emissions ASC
    """).fetchdf()
print(result)
# Out:
#   iso3_country  total_emissions
# 0          SWE        1567521.0
# 1          NOR        1589179.0
# 2          FIN        3841546.0
# 3          DNK        5605587.0

# %%
result = conn.execute("""
    SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
    WHERE iso3_country IN ('DNK','SWE', 'NOR', 'FIN')
    AND start_time >= '2024-01-01'
    AND start_time < '2025-01-01'
    ORDER BY total_emissions ASC
    """).fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 result = conn.execute("""
#       2     SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
#       3     WHERE iso3_country IN ('DNK','SWE', 'NOR', 'FIN')
#       4     AND start_time >= '2024-01-01'
#
# BinderException: Binder Error: Referenced column "total_emissions" not found in FROM clause!
# Candidate bindings: "start_time", "emissions_quantity_units", "emissions_quantity", "temporal_granularity", "iso3_country"
#
# LINE 6:     ORDER BY total_emissions ASC
#                      ^

# %%
result = conn.execute("""
    SELECT iso3_country, emissions_quantity FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 co2e.csv')
    WHERE iso3_country IN ('DNK','SWE', 'NOR', 'FIN')
    AND start_time >= '2024-01-01'
    AND start_time < '2025-01-01'
    ORDER BY emissions_quantity ASC
    """).fetchdf()
print(result)
# Out:
#   iso3_country  emissions_quantity
# 0          SWE           1567521.0
# 1          NOR           1589179.0
# 2          FIN           3841546.0
# 3          DNK           5605587.0

# %%
result = conn.execute("""
    SELECT SUM(emissions_quantity) AS wrong_total
    FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2*.csv')
    WHERE start_time >= '2023-01-01'
    AND start_time < '2024-01-01'
""").fetchdf()
print(result)
# Out:
#    wrong_total
# 0   11231238.0

# %%
result = conn.execute("""
    SELECT SUM(emissions_quantity) AS correct_total
    FROM read_csv_auto('data/electricity-generation_country_emissions_v5_5_0 dk co2*.csv')
    WHERE start_time >= '2023-01-01'
    AND start_time < '2024-01-01'
    AND gas = 'co2e_100yr'
""").fetchdf()
print(result)
# Out:
#    correct_total
# 0      5615619.0

# %% [markdown]
# entering wrong numbers is not cool!

# %%
result = conn.execute("""
    SELECT 
        subsector,
        SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2023-01-01'
    AND start_time < '2024-01-01'
    GROUP BY subsector
    ORDER BY total_emissions DESC
""").fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = conn.execute("""
#       2     SELECT
#       3         subsector,
#       4         SUM(emissions_quantity) AS total_emissions
#
# NameError: name 'conn' is not defined

# %%
import duckdb

conn = duckdb.connect()

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT 
        subsector,
        SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2023-01-01'
    AND start_time < '2024-01-01'
    GROUP BY subsector
    ORDER BY total_emissions DESC
""").fetchdf()
print(result)
# Out:
#                                  subsector  total_emissions
# 0                      road-transportation     1.067348e+07
# 1                   electricity-generation     5.615619e+06
# 2                        domestic-shipping     4.810512e+06
# 3    enteric-fermentation-cattle-operation     4.152355e+06
# 4       manure-management-cattle-operation     3.250080e+06
# ..                                     ...              ...
# 63  incineration-and-open-burning-of-waste     0.000000e+00
# 64                          bauxite-mining     0.000000e+00
# 65                          net-shrubgrass    -6.004851e+04
# 66                             net-wetland    -1.547467e+05
# 67                                removals    -1.309878e+06
#
# [68 rows x 2 columns]

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT
        year, subsector, SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2015-01-01'
    AND start_time < '2025-01-01'
    GROUP BY subsector
    ORDER BY total_emissions DESC
""").fetchdf()
print(result)
# Out:
#                                 subsector  total_emissions
# 0                     road-transportation     1.123353e+08
# 1                  electricity-generation     8.056446e+07
# 2   enteric-fermentation-cattle-operation     3.946121e+07
# 3           residential-onsite-fuel-usage     3.479847e+07
# 4                       domestic-shipping     3.335668e+07
# ..                                    ...              ...
# 63                            coal-mining     0.000000e+00
# 64                         net-shrubgrass    -1.057784e+05
# 65                            net-wetland    -2.598349e+05
# 66                        net-forest-land    -4.566220e+05
# 67                               removals    -1.308903e+07
#
# [68 rows x 2 columns]

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT
        year, subsector, SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2015-01-01'
    AND start_time < '2025-01-01'
    GROUP BY subsector
    ORDER BY year ASC, total_emissions DESC
""").fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# Cell In[2], line 4
#       1 import duckdb
#       2
#       3 conn = duckdb.connect()
# ----> 4 result = conn.execute("""
#       5     SELECT
#       6         year, subsector, SUM(emissions_quantity) AS total_emissions
#       7     FROM read_csv_auto('data/*dk co2e.csv')
#
# ParserException: Parser Error: syntax error at or near "ORDER"
#
# LINE 9:     ORDER BY total_emissions DESC
#             ^

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT
        year, subsector, SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2015-01-01'
    AND start_time < '2025-01-01'
    GROUP BY subsector
    ORDER BY year ASC, total_emissions DESC
""").fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[3], line 4
#       1 import duckdb
#       2
#       3 conn = duckdb.connect()
# ----> 4 result = conn.execute("""
#       5     SELECT
#       6         year, subsector, SUM(emissions_quantity) AS total_emissions
#       7     FROM read_csv_auto('data/*dk co2e.csv')
#
# BinderException: Binder Error: Referenced column "year" not found in FROM clause!
# Candidate bindings: "sector", "start_time", "created_date", "emissions_quantity_units", "gas"
#
# LINE 3:         year, subsector, SUM(emissions_quantity) AS total_emissions
#                 ^

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT
        year, subsector, SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2015-01-01'
    AND start_time < '2025-01-01'
    GROUP BY subsector
    ORDER BY start_time ASC, total_emissions DESC
""").fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[4], line 4
#       1 import duckdb
#       2
#       3 conn = duckdb.connect()
# ----> 4 result = conn.execute("""
#       5     SELECT
#       6         year, subsector, SUM(emissions_quantity) AS total_emissions
#       7     FROM read_csv_auto('data/*dk co2e.csv')
#
# BinderException: Binder Error: Referenced column "year" not found in FROM clause!
# Candidate bindings: "sector", "start_time", "created_date", "emissions_quantity_units", "gas"
#
# LINE 3:         year, subsector, SUM(emissions_quantity) AS total_emissions
#                 ^

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT
        start_time, subsector, SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2015-01-01'
    AND start_time < '2025-01-01'
    GROUP BY subsector
    ORDER BY start_time ASC, total_emissions DESC
""").fetchdf()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 import duckdb
#       2
#       3 conn = duckdb.connect()
# ----> 4 result = conn.execute("""
#       5     SELECT
#       6         start_time, subsector, SUM(emissions_quantity) AS total_emissions
#       7     FROM read_csv_auto('data/*dk co2e.csv')
#
# BinderException: Binder Error: column "start_time" must appear in the GROUP BY clause or must be part of an aggregate function.
# Either add it to the GROUP BY list, or use "ANY_VALUE(start_time)" if the exact value of "start_time" is not important.
#
# LINE 3:         start_time, subsector, SUM(emissions_quantity) AS total_emi...
#                 ^

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT
        YEAR(start_time:: DATE) AS year, subsector, SUM(emissions_quantity) AS total_emissions
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2015-01-01'
    AND start_time < '2025-01-01'
    GROUP BY year, subsector
    ORDER BY year ASC, total_emissions DESC
""").fetchdf()
print(result)
# Out:
#      year                      subsector  total_emissions
# 0    2015            road-transportation     1.144478e+07
# 1    2015         electricity-generation     1.036778e+07
# 2    2015                net-forest-land     6.869194e+06
# 3    2015                       removals     6.195577e+06
# 4    2015  residential-onsite-fuel-usage     3.789121e+06
# ..    ...                            ...              ...
# 675  2024        forest-land-degradation     0.000000e+00
# 676  2024                  copper-mining     0.000000e+00
# 677  2024                    iron-mining     0.000000e+00
# 678  2024   petrochemical-steam-cracking     0.000000e+00
# 679  2024                 bauxite-mining     0.000000e+00
#
# [680 rows x 3 columns]

# %%
import duckdb

conn = duckdb.connect()
result = conn.execute("""
    SELECT
        YEAR(start_time:: DATE) AS year, subsector, ROUND(SUM(emissions_quantity) / 1000000, 2) AS emissions_million_tonnes
    FROM read_csv_auto('data/*dk co2e.csv')
    WHERE start_time >= '2015-01-01'
    AND start_time < '2025-01-01'
    GROUP BY year, subsector
    ORDER BY year ASC, emissions_million_tonnes DESC
""").fetchdf()
print(result)
# Out:
#      year                               subsector  emissions_million_tonnes
# 0    2015                     road-transportation                     11.44
# 1    2015                  electricity-generation                     10.37
# 2    2015                         net-forest-land                      6.87
# 3    2015                                removals                      6.20
# 4    2015           residential-onsite-fuel-usage                      3.79
# ..    ...                                     ...                       ...
# 675  2024                          cropland-fires                      0.00
# 676  2024                                aluminum                      0.00
# 677  2024  incineration-and-open-burning-of-waste                      0.00
# 678  2024                                removals                      0.00
# 679  2024                        shrubgrass-fires                      0.00
#
# [680 rows x 3 columns]
